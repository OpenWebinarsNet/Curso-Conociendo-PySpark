# %% [markdown]
# ##  Dataframes Fundamentals
# > Este notebook está desarrollado por Mg. Ing. Layla Scheli

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) spark.createDataFrame()
#
# > Función que te permite crear dataframes

# %%
df=  [{'nombre': 'Layla', 'edad': 30 , 'ciudad': 'Rosario' },
      {'nombre': 'Jose', 'edad': 30 , 'ciudad': 'Lima'},
      {'nombre': 'Juan', 'edad': 20 , 'ciudad': 'cdmx'}]

dfCustomer=spark.createDataFrame(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) count()
#
# > Retorna el nro. de filas del dataset

# %%
dfCustomer.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: 3</div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) printSchema()
#
# > Función que que devuelve la estructura del dataframe

# %%
dfCustomer.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- ciudad: string (nullable = true)
# -- edad: long (nullable = true)
# -- nombre: string (nullable = true)
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) show(..)
#
# Esta función me permite visualizar los datos
#
# Parámetros opcionales:
# * **n**: Número de filas que queremos visualizar.
# * **truncate**: Si el valor es en True, las columnas de más de 20 caracteres serán omitidos

# %%
dfCustomer.show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----+------+
#  ciudad|edad|nombre|
# +-------+----+------+
# Rosario|  28| Layla|
#    Lima|  30|  Jose|
# +-------+----+------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) display(..)
#
# Podemos utilizar tambien la función display para la visualización de datos y ver los datos de otra manera

# %%
display(dfCustomer)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ciudad</th><th>edad</th><th>nombre</th></tr></thead><tbody><tr><td>Rosario</td><td>28</td><td>Layla</td></tr><tr><td>Lima</td><td>30</td><td>Jose</td></tr><tr><td>Medellin</td><td>20</td><td>Juan</td></tr></tbody></table></div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) limit(..)
#
# La principal diferencia entre display y show , es que en show podemos indicarle el nro. de filas
#
# > Esta función me permite crear un nuevo dataset donde le pueda colocar un límite de filas

# %%
dfCustomerLimit = dfCustomer.limit(2) 

dfCustomerLimit.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----+------+
#  ciudad|edad|nombre|
# +-------+----+------+
# Rosario|  28| Layla|
#    Lima|  30|  Jose|
# +-------+----+------+
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) select(..)
#
# Esta función te permite seleccionar algunas columnas de un datfrme

# %%
# Transformamos la data, quedandonos solo con 2 columnas
dfCustomerSelect = (dfCustomer
  .select("nombre","edad") 
)
# Imprimimos el schema
dfCustomerSelect.printSchema()

#Visualizamos por pantalla
dfCustomerSelect.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- nombre: string (nullable = true)
# -- edad: long (nullable = true)
#
# +------+----+
# nombre|edad|
# +------+----+
#  Layla|  28|
#   Jose|  30|
#   Juan|  20|
# +------+----+
#
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) drop(..)
#
# La función drop() te permite eliminar columnas de un dataframe

# %%
dfCustomerDrop= dfCustomer.drop("edad")

dfCustomerDrop.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+------+
#   ciudad|nombre|
# +--------+------+
#  Rosario| Layla|
#     Lima|  Jose|
# Medellin|  Juan|
# +--------+------+
#
# </div>
